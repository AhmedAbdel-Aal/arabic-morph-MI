# %%
# Cell 1 - Environment Setup
# !pip install -q "transformers==4.56.2" "accelerate==1.0.1" sentencepiece
# !pip install -q "numpy==2.0.2" "scipy==1.16.2" "scikit-learn==1.7.2" "matplotlib==3.10.6"

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "no cuda")
# Out:
# True
# Tesla T4

# %%
# !git clone https://github.com/AhmedAbdel-Aal/arabic-morph-MI.git || true
# Out:
# Cloning into 'arabic-morph-MI'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 101 (delta 38), reused 84 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (101/101), 978.08 KiB | 14.60 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd /content/arabic-morph-MI
# Out:
# /content/arabic-morph-MI

# %%
# run E03
#!MODEL=Qwen/Qwen3-1.7B-Base SURFACE=base POOLING=last RUN_ID=E03 BATCH_SIZE=4 bash scripts/colab_run.sh
# Out:
# [21:37:38] Starting Colab run
# repo:       https://github.com/AhmedAbdel-Aal/arabic-morph-MI.git
# workdir:    /content/arabic-morph-MI
# model:      Qwen/Qwen3-1.7B-Base
# surface:    base
# pooling:    last
# batch size: 4
# data path:  data/productivity_dataset.json
#
# [21:37:38] Cloning or updating repository
# Already up to date.
#
# [21:37:38] Installing Python dependencies
# ...
# Obtaining file:///content/arabic-morph-MI
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for arabic-morph-mi (pyproject.toml) ... done
#   Created wheel for arabic-morph-mi: filename=arabic_morph_mi-0.1.0-0.editable-py3-none-any.whl size=1700 sha256=d896ffc48b72a2a2f1367aeb9363e659133b57d46b39ca9fbaa3466f78c06369
# ...

# %%
# run E04
# !MODEL=Qwen/Qwen3-1.7B-Base SURFACE=base POOLING=first RUN_ID=E04a BATCH_SIZE=4 bash scripts/colab_run.sh
# Out:
# [22:00:19] Starting Colab run
# repo:       https://github.com/AhmedAbdel-Aal/arabic-morph-MI.git
# workdir:    /content/arabic-morph-MI
# model:      Qwen/Qwen3-1.7B-Base
# surface:    base
# pooling:    first
# batch size: 4
# data path:  data/productivity_dataset.json
#
# [22:00:19] Cloning or updating repository
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 12 (delta 7), reused 12 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 2.56 KiB | 328.00 KiB/s, done.
# From https://github.com/AhmedAbdel-Aal/arabic-morph-MI
#    f752d35..c9b66bd  main       -> origin/main
# Updating f752d35..c9b66bd
# Fast-forward
#  README.md                                          |  11 +-
#  colab/colab_vscode_notebook.ipynb                  | 170 +++++++++++++++++----
#  experiments.md                                     |  16 +-
# ...

# %%
# !git config --global user.name "AhmedAbdel-Aal"
# !git config --global user.email "ahmedabdou1789@gmail.com"

import os, getpass
os.environ["GITHUB_TOKEN"] = getpass.getpass("GitHub token: ")

# %%
 # !mv results/20260502T220048Z_Qwen3-1.7B-Base_base_first results/E04a

# %%
# !git add results/

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   results/E04a/curves.png
# 	new file:   results/E04a/representation_diagnostics.json
# 	new file:   results/E04a/results.json
# 	new file:   results/E04a/tokenization_diagnostics.json
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	arabic-morph-MI/

# %%
  # !find results/E04a -maxdepth 1 -type f -print
# Out:
# results/E04a/tokenization_diagnostics.json
# results/E04a/representation_diagnostics.json
# results/E04a/curves.png
# results/E04a/results.json

# %%
# !git commit -m "Add E04 run"
# Out:
# [main 3315286] Add E04 run
#  4 files changed, 7613 insertions(+)
#  create mode 100644 results/E04a/curves.png
#  create mode 100644 results/E04a/representation_diagnostics.json
#  create mode 100644 results/E04a/results.json
#  create mode 100644 results/E04a/tokenization_diagnostics.json

# %%
# !git remote set-url origin https://x-access-token:${GITHUB_TOKEN}@github.com/AhmedAbdel-Aal/arabic-morph-MI.git

# %%
# !git push origin main
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 245.73 KiB | 12.29 MiB/s, done.
# Total 8 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/AhmedAbdel-Aal/arabic-morph-MI.git
#    c9b66bd..3315286  main -> main
